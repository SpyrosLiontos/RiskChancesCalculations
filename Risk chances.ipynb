# %%
# %display latex

# %%
def battle(stratosamunomenou,stratosepitithomenou):
    nikhamunomenou=var('nikhamunomenou');
    nikhepiti=var('nikhepiti');
    stratosepi=stratosepitithomenou;
    stratosamu=stratosamunomenou;
    maxizaries=var('maxizaries');
    if stratosepi>stratosamu:
        maxizaries=stratosepi*100
    if stratosamu>stratosepi or stratosamu==stratosepi:
        maxizaries=stratosamu*100
    for ii in range(maxizaries):
        if stratosepi<=0:
            nikhamunomenou=1;
            nikhepiti=0;
            break
        if stratosamu<=0:
            nikhepiti=1;
            nikhamunomenou=0;
            break
        if stratosepi==2:
            if stratosamu!=1:
                epi=[randint(1,6) for i in range(2)]
                amu=[randint(1,6) for i in range(2)]
                epimax=max(epi);
                epimin=min(epi);
                amumax=max(amu);
                amumin=min(amu);
                if epimax>amumax:
                    stratosamu=stratosamu-1;
                if epimax<=amumax:
                    stratosepi=stratosepi-1;
                if epimin>amumin:
                    stratosamu=stratosamu-1;
                if epimin<=amumin:
                    stratosepi=stratosepi-1;
                print(epi,epimax,0,epimin,'',amu,amumax,amumin,'    ',stratosamu,stratosepi)
                if stratosepi<=0:
                    nikhamunomenou=1;
                    nikhepiti=0;
                    break
                if stratosamu<=0:
                    nikhepiti=1;
                    nikhamunomenou=0;
                    break                 
            if stratosamu==1:
                epi=[randint(1,6) for i in range(2)];
                amu=randint(1,6);
                epimax=max(epi);
                epimin=min(epi);
                if epimax>amu:
                    stratosamu=stratosamu-1;
                if epimax<=amu:
                    stratosepi=stratosepi-1;
                print(epi,epimax,epimin,0,'',amu,amu,0,'    ',stratosamu,stratosepi)
                if stratosepi<=0:
                    nikhamunomenou=1;
                    nikhepiti=0;
                    break
                if stratosamu<=0:
                    nikhepiti=1;
                    nikhamunomenou=0;
                    break
        if stratosamu==1 and stratosepi==1:
            epi=randint(1,6)
            amu=randint(1,6)
            if epi>amu:
                stratosamu=stratosamu-1;
            if epi<=amu:
                stratosepi=stratosepi-1;
            print(epi,epi,0,0,'',amu,amu,0,'    ',stratosamu,stratosepi)
            if stratosepi<=0:                    
                nikhamunomenou=1;
                nikhepiti=0;
                break
            if stratosamu<=0:
                nikhepiti=1;
                nikhamunomenou=0;
                break
        if stratosepi==1 and stratosamu!=1:
            epi=randint(1,6);
            amu=[randint(1,6) for i in range(2)];
            amumax=max(amu);
            amumin=min(amu);
            if epi>amumax:
                stratosamu=stratosamu-1;
            if epi<=amumax:
                stratosepi=stratosepi-1;
            print(epi,epi,0,0,'',amu,amumax,amumin,'    ',stratosamu,stratosepi)
            if stratosepi<=0:
                nikhamunomenou=1;
                nikhepiti=0;
                break
            if stratosamu<=0:
                nikhepiti=1;
                nikhamunomenou=0;
                break  
        if stratosamu==1:
            if stratosepi!=2:
                epi=[randint(1,6) for i in range(3)]
                epi.sort()
                amu=randint(1,6)
                epimax=max(epi);
                epimin=min(epi);
                epimiddle=epi[1];
                if epimax>amu:
                    stratosamu=stratosamu-1;
                if epimax<=amu:
                    stratosepi=stratosepi-1;
                print(epi,epimax,epimiddle,epimin,'',amu,amu,0,'    ',stratosamu,stratosepi)
                if stratosepi<=0:
                    nikhamunomenou=1;
                    nikhepiti=0;
                    break
                if stratosamu<=0:
                    nikhepiti=1;
                    nikhamunomenou=0;
                    break 
        if stratosepi!=2 and stratosamu!=1 and stratosepi!=1:
            epi=[randint(1,6) for i in range(3)]
            epi.sort()
            amu=[randint(1,6) for i in range(2)]
            amu.sort()
            epimax=max(epi);
            epimin=min(epi);
            epimiddle=epi[1];
            amumax=max(amu);
            amumin=min(amu);
            if epimax>amumax:
                stratosamu=stratosamu-1;
            if epimax<=amumax:
                stratosepi=stratosepi-1;
            if epimiddle>amumin:
                stratosamu=stratosamu-1;
            if epimiddle<=amumin:
                stratosepi=stratosepi-1;
            print(epi,epimax,epimiddle,epimin,'',amu,amumax,amumin,'    ',stratosamu,stratosepi)
    print('nikhamunomenou=',nikhamunomenou,'','nikhepiti=',nikhepiti)
    return nikhamunomenou,nikhepiti

# %%
battle(6,12)
# Out:
# [2, 5, 5] 5 5 2  [3, 5] 5 3      5 11
# [1, 2, 4] 4 2 1  [2, 3] 3 2      4 10
# [1, 2, 3] 3 2 1  [2, 2] 2 2      3 9
# [2, 3, 5] 5 3 2  [2, 5] 5 2      2 8
# [3, 5, 6] 6 5 3  [1, 3] 3 1      0 8
# nikhamunomenou= 0  nikhepiti= 1
# (0, 1)

# %%
x=battle(10,14);
# Out:
# [2, 2, 4] 4 2 2  [2, 4] 4 2      10 12
# [3, 4, 5] 5 4 3  [4, 6] 6 4      10 10
# [5, 6, 6] 6 6 5  [3, 3] 3 3      8 10
# [2, 2, 6] 6 2 2  [2, 3] 3 2      7 9
# [4, 5, 6] 6 5 4  [1, 2] 2 1      5 9
# [1, 1, 2] 2 1 1  [5, 6] 6 5      5 7
# [2, 4, 5] 5 4 2  [2, 6] 6 2      4 6
# [2, 3, 4] 4 3 2  [1, 4] 4 1      3 5
# [1, 2, 4] 4 2 1  [2, 3] 3 2      2 4
# [1, 6, 6] 6 6 1  [1, 1] 1 1      0 4
# nikhamunomenou= 0  nikhepiti= 1

# %%
x[1]
# Out:
# 1

# %%
posa=var('posa');
pose=var('pose');
data1=[];data2=[];
posa,pose=0.,0.;
numbat=1000;
for ii in range(numbat):
    x=battle(12,12);
    posa=posa+x[0]
    pose=pose+x[1]
    data1.append([ii,posa])
    data2.append([ii,pose])
    print(posa,pose)
# Out:
# [2, 4, 5] 5 4 2  [6, 6] 6 6      12 10
# [1, 2, 5] 5 2 1  [2, 5] 5 2      12 8
# [1, 2, 6] 6 2 1  [1, 3] 3 1      10 8
# [1, 2, 3] 3 2 1  [4, 5] 5 4      10 6
# [4, 4, 6] 6 4 4  [1, 2] 2 1      8 6
# [1, 2, 6] 6 2 1  [1, 5] 5 1      6 6
# [1, 2, 4] 4 2 1  [2, 5] 5 2      6 4
# [1, 2, 5] 5 2 1  [3, 4] 4 3      5 3
# [4, 6, 6] 6 6 4  [3, 4] 4 3      3 3
# [1, 5, 5] 5 5 1  [1, 5] 5 1      2 2
# [6, 2] 6 0 2  [3, 6] 6 3      2 0
# nikhamunomenou= 1  nikhepiti= 0
# 1.00000000000000 0.000000000000000
# [2, 3, 4] 4 3 2  [2, 5] 5 2      11 11
# [3, 4, 4] 4 4 3  [4, 5] 5 4      11 9
# [1, 4, 5] 5 4 1  [2, 6] 6 2      10 8
# [1, 4, 5] 5 4 1  [1, 6] 6 1      9 7
# [2, 4, 6] 6 4 2  [1, 4] 4 1      7 7
# [3, 3, 6] 6 3 3  [5, 6] 6 5      7 5
# [1, 3, 4] 4 3 1  [1, 5] 5 1      6 4
# [1, 4, 4] 4 4 1  [2, 3] 3 2      4 4
# [2, 5, 6] 6 5 2  [5, 6] 6 5      4 2
# [3, 6] 6 0 3  [2, 4] 4 2      2 2
# [5, 3] 5 0 3  [5, 1] 5 1      1 1
# [4, 5] 5 4 0  2 2 0      0 1
# nikhamunomenou= 0  nikhepiti= 1
# ...

# %%
f1=points(data1,legend_label='$Αμυνομενος$',color='black',axes_labels=['$αριθμος μαχων$','$επιτυχιες$'])
f2=points(data2,legend_label='$Επιτιθεμενος$',color='red')
f1+f2
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
line(data1)+line(data2)
# Out:
# Graphics object consisting of 2 graphics primitives

# %% [markdown]
# no prints

# %%
def battle(stratosamunomenou,stratosepitithomenou):
    nikhamunomenou=var('nikhamunomenou');
    nikhepiti=var('nikhepiti');
    stratosepi=stratosepitithomenou;
    stratosamu=stratosamunomenou;
    maxizaries=var('maxizaries');
    if stratosepi>stratosamu:
        maxizaries=stratosepi*100
    if stratosamu>stratosepi or stratosamu==stratosepi:
        maxizaries=stratosamu*100
    for ii in range(maxizaries):
        if stratosepi<=0:
            nikhamunomenou=1;
            nikhepiti=0;
            break
        if stratosamu<=0:
            nikhepiti=1;
            nikhamunomenou=0;
            break
        if stratosepi==2:
            if stratosamu!=1:
                epi=[randint(1,6) for i in range(2)]
                amu=[randint(1,6) for i in range(2)]
                epimax=max(epi);
                epimin=min(epi);
                amumax=max(amu);
                amumin=min(amu);
                if epimax>amumax:
                    stratosamu=stratosamu-1;
                if epimax<=amumax:
                    stratosepi=stratosepi-1;
                if epimin>amumin:
                    stratosamu=stratosamu-1;
                if epimin<=amumin:
                    stratosepi=stratosepi-1;
                if stratosepi<=0:
                    nikhamunomenou=1;
                    nikhepiti=0;
                    break
                if stratosamu<=0:
                    nikhepiti=1;
                    nikhamunomenou=0;
                    break                 
            if stratosamu==1:
                epi=[randint(1,6) for i in range(2)];
                amu=randint(1,6);
                epimax=max(epi);
                epimin=min(epi);
                if epimax>amu:
                    stratosamu=stratosamu-1;
                if epimax<=amu:
                    stratosepi=stratosepi-1;
                if stratosepi<=0:
                    nikhamunomenou=1;
                    nikhepiti=0;
                    break
                if stratosamu<=0:
                    nikhepiti=1;
                    nikhamunomenou=0;
                    break
        if stratosamu==1 and stratosepi==1:
            epi=randint(1,6)
            amu=randint(1,6)
            if epi>amu:
                stratosamu=stratosamu-1;
            if epi<=amu:
                stratosepi=stratosepi-1;
            if stratosepi<=0:                    
                nikhamunomenou=1;
                nikhepiti=0;
                break
            if stratosamu<=0:
                nikhepiti=1;
                nikhamunomenou=0;
                break
        if stratosepi==1 and stratosamu!=1:
            epi=randint(1,6);
            amu=[randint(1,6) for i in range(2)];
            amumax=max(amu);
            amumin=min(amu);
            if epi>amumax:
                stratosamu=stratosamu-1;
            if epi<=amumax:
                stratosepi=stratosepi-1;
            if stratosepi<=0:
                nikhamunomenou=1;
                nikhepiti=0;
                break
            if stratosamu<=0:
                nikhepiti=1;
                nikhamunomenou=0;
                break  
        if stratosamu==1:
            if stratosepi!=2:
                epi=[randint(1,6) for i in range(3)]
                epi.sort()
                amu=randint(1,6)
                epimax=max(epi);
                epimin=min(epi);
                epimiddle=epi[1];
                if epimax>amu:
                    stratosamu=stratosamu-1;
                if epimax<=amu:
                    stratosepi=stratosepi-1;
                if stratosepi<=0:
                    nikhamunomenou=1;
                    nikhepiti=0;
                    break
                if stratosamu<=0:
                    nikhepiti=1;
                    nikhamunomenou=0;
                    break 
        if stratosepi!=2 and stratosamu!=1 and stratosepi!=1:
            epi=[randint(1,6) for i in range(3)]
            epi.sort()
            amu=[randint(1,6) for i in range(2)]
            amu.sort()
            epimax=max(epi);
            epimin=min(epi);
            epimiddle=epi[1];
            amumax=max(amu);
            amumin=min(amu);
            if epimax>amumax:
                stratosamu=stratosamu-1;
            if epimax<=amumax:
                stratosepi=stratosepi-1;
            if epimiddle>amumin:
                stratosamu=stratosamu-1;
            if epimiddle<=amumin:
                stratosepi=stratosepi-1;
    return nikhamunomenou,nikhepiti

# %%
posa=var('posa');
pose=var('pose');
data1=[];data2=[];
posa,pose=0.,0.;
numbat=1000;
for ii in range(numbat):
    x=battle(14,12);
    posa=posa+x[0]
    pose=pose+x[1]
    data1.append([ii,posa])
    data2.append([ii,pose])
print(posa,pose)
# Out:
# 544.000000000000 456.000000000000

# %%
f1=points(data1,legend_label='$Αμυνομενος$',color='black',axes_labels=['$αριθμος μαχων$','$επιτυχιες$'])
f2=points(data2,legend_label='$Επιτιθομενος$',color='red')
f1+f2
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
def belt(sa,se,nb):
    posa=var('posa');
    pose=var('pose');
    data1=[];data2=[];
    posa,pose=0.,0.;
    numbat=nb;
    for ii in range(numbat):
        x=battle(sa,se);
        posa=posa+x[0]
        pose=pose+x[1]
    return(posa,pose)

# %%
def kk(k,maxarmy):
    for ii in range(maxarmy):
        for i in range(maxarmy):
            y=belt(i,ii,k)
            if y[0]==y[1]:
                print('ιδιο ποσοστο επιτυχιας στους ',i,'αμυνομενους',ii,'επιτιθομενους')

# %%
kk(100,30)
# Out:
# ιδιο ποσοστο επιτυχιας στους  18 αμυνομενους 15 επιτιθομενους
# ιδιο ποσοστο επιτυχιας στους  28 αμυνομενους 24 επιτιθομενους

# %%
def kk(k,maxarmy):
    l=[];
    for ii in range(maxarmy):
        for i in range(maxarmy):
            y=belt(i,ii,k)
            if y[0]==y[1]:
                l.append([i,ii]);
                return i,ii

# %%
nn=[];mm=[];bb=[];
for ii in range(50):
    nn.append(kk(50,30));
    mm.append(kk(50,30));

# %% [markdown]
# attempt to find same number of armies and same number of chances

# %%
bb=[[0,0]];
oll=0;
for i in range(50):
    for j in range(50):
        if mm[j]==nn[i]:
            oll=oll+1;
for u in range(oll):
    for j in range(50):
        if bb[u]==mm[j]:
            print('keno')
        else:
            sdfds=mm[j];
            bb.append([sdfds]);
            print('ιδιο ποσοστο επιτυχιας στους ',mm[j],'αμυνομενους','επιτιθομενους')

# %%
bb
